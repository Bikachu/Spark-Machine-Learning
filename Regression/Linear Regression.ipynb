# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName('Irex').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.regression import LinearRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training = spark.read.format('libsvm').load('/FileStore/tables/sample_linear_regression_data.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+--------------------+
#               label|            features|
# +-------------------+--------------------+
#  -9.490009878824548|(10,[0,1,2,3,4,5,...|
#  0.2577820163584905|(10,[0,1,2,3,4,5,...|
#  -4.438869807456516|(10,[0,1,2,3,4,5,...|
# -19.782762789614537|(10,[0,1,2,3,4,5,...|
#  -7.966593841555266|(10,[0,1,2,3,4,5,...|
#  -7.896274316726144|(10,[0,1,2,3,4,5,...|
#  -8.464803554195287|(10,[0,1,2,3,4,5,...|
#  2.1214592666251364|(10,[0,1,2,3,4,5,...|
#  1.0720117616524107|(10,[0,1,2,3,4,5,...|
# -13.772441561702871|(10,[0,1,2,3,4,5,...|
#  -5.082010756207233|(10,[0,1,2,3,4,5,...|
#   7.887786536531237|(10,[0,1,2,3,4,5,...|
#  14.323146365332388|(10,[0,1,2,3,4,5,...|
# -20.057482615789212|(10,[0,1,2,3,4,5,...|
# -0.8995693247765151|(10,[0,1,2,3,4,5,...|
#  -19.16829262296376|(10,[0,1,2,3,4,5,...|
#   5.601801561245534|(10,[0,1,2,3,4,5,...|
# -3.2256352187273354|(10,[0,1,2,3,4,5,...|
#  1.5299675726687754|(10,[0,1,2,3,4,5,...|
#  -0.250102447941961|(10,[0,1,2,3,4,5,...|
# +-------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
lr  = LinearRegression(featuresCol='features', 
                       labelCol= 'label',
                        predictionCol = 'prediction')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lrModel = lr.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lrModel.coefficients
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>DenseVector([0.0073, 0.8314, -0.8095, 2.4412, 0.5192, 1.1535, -0.2989, -0.5129, -0.6197, 0.6956])
# </div>

# %%
lrModel.intercept
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>0.14228558260358093
# </div>

# %%
training_summary = lrModel.summary
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
training_summary.r2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>0.027839179518600154
# </div>

# %%
# train and test split 
all_data  = spark.read.format('libsvm').load('/FileStore/tables/sample_linear_regression_data.txt')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_data, test_data = all_data.randomSplit([0.7, 0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+--------------------+
#               label|            features|
# +-------------------+--------------------+
# -28.046018037776633|(10,[0,1,2,3,4,5,...|
# -26.805483428483072|(10,[0,1,2,3,4,5,...|
# -23.487440120936512|(10,[0,1,2,3,4,5,...|
# -22.949825936196074|(10,[0,1,2,3,4,5,...|
# -22.837460416919342|(10,[0,1,2,3,4,5,...|
# -20.212077258958672|(10,[0,1,2,3,4,5,...|
# -20.057482615789212|(10,[0,1,2,3,4,5,...|
# -19.884560774273424|(10,[0,1,2,3,4,5,...|
# -19.872991038068406|(10,[0,1,2,3,4,5,...|
# -19.782762789614537|(10,[0,1,2,3,4,5,...|
#  -19.16829262296376|(10,[0,1,2,3,4,5,...|
#  -18.27521356600463|(10,[0,1,2,3,4,5,...|
# -17.428674570939506|(10,[0,1,2,3,4,5,...|
#  -17.32672073267595|(10,[0,1,2,3,4,5,...|
# -17.065399625876015|(10,[0,1,2,3,4,5,...|
# -17.026492264209548|(10,[0,1,2,3,4,5,...|
#  -16.71909683360509|(10,[0,1,2,3,4,5,...|
#  -16.26143027545273|(10,[0,1,2,3,4,5,...|
# -16.151349351277112|(10,[0,1,2,3,4,5,...|
# -15.951512565794573|(10,[0,1,2,3,4,5,...|
# +-------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
test_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+--------------------+
#               label|            features|
# +-------------------+--------------------+
# -28.571478869743427|(10,[0,1,2,3,4,5,...|
# -26.736207182601724|(10,[0,1,2,3,4,5,...|
#  -23.51088409032297|(10,[0,1,2,3,4,5,...|
# -21.432387764165806|(10,[0,1,2,3,4,5,...|
#  -19.66731861537172|(10,[0,1,2,3,4,5,...|
# -19.402336030214553|(10,[0,1,2,3,4,5,...|
# -18.845922472898582|(10,[0,1,2,3,4,5,...|
# -17.803626188664516|(10,[0,1,2,3,4,5,...|
# -17.494200356883344|(10,[0,1,2,3,4,5,...|
# -16.692207021311106|(10,[0,1,2,3,4,5,...|
#  -16.08565904102149|(10,[0,1,2,3,4,5,...|
# -15.780685032623301|(10,[0,1,2,3,4,5,...|
# -15.732088272239245|(10,[0,1,2,3,4,5,...|
# -15.375857723312297|(10,[0,1,2,3,4,5,...|
# -15.359544879832677|(10,[0,1,2,3,4,5,...|
# -15.348871155379253|(10,[0,1,2,3,4,5,...|
# -15.334767479922341|(10,[0,1,2,3,4,5,...|
# -14.762758252931127|(10,[0,1,2,3,4,5,...|
# -12.977848725392104|(10,[0,1,2,3,4,5,...|
# -12.558575788856189|(10,[0,1,2,3,4,5,...|
# +-------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
correct_model = lr.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_result = correct_model.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
unlabeled_data = test_data.select('features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = correct_model.transform(unlabeled_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+
#             features|          prediction|
# +--------------------+--------------------+
# (10,[0,1,2,3,4,5,...|  0.2384706522768058|
# (10,[0,1,2,3,4,5,...| -2.5945902651327044|
# (10,[0,1,2,3,4,5,...|-0.28478224494168236|
# (10,[0,1,2,3,4,5,...|  0.8008791443741912|
# (10,[0,1,2,3,4,5,...| -0.8025706386424055|
# (10,[0,1,2,3,4,5,...| -0.3792423266895911|
# (10,[0,1,2,3,4,5,...|   2.787800563199732|
# (10,[0,1,2,3,4,5,...| -1.0242165510785255|
# (10,[0,1,2,3,4,5,...|  -1.861444453315789|
# (10,[0,1,2,3,4,5,...|  0.6483555118407134|
# (10,[0,1,2,3,4,5,...| -0.6593914055177298|
# (10,[0,1,2,3,4,5,...|  1.8482167115331611|
# (10,[0,1,2,3,4,5,...|   2.067169697526534|
# (10,[0,1,2,3,4,5,...|  0.6545441341488112|
# (10,[0,1,2,3,4,5,...|   2.226887471908358|
# (10,[0,1,2,3,4,5,...|  -1.348574399321889|
# (10,[0,1,2,3,4,5,...|  2.4887381394252546|
# (10,[0,1,2,3,4,5,...| -1.2781621659645679|
# (10,[0,1,2,3,4,5,...|  0.8074726530697698|
# (10,[0,1,2,3,4,5,...|  1.1842063669801812|
# +--------------------+--------------------+
# only showing top 20 rows
#
# </div>
